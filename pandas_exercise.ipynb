# %%
import pandas as pd

# %%
s = pd.Series([21,23,25,26,24,28], name ="Age")
s
# Out:
# 0    21
# 1    23
# 2    25
# 3    26
# 4    24
# 5    28
# Name: Age, dtype: int64

# %%
s = pd.Series([21,26,23,25,24,26], name="Age" ,
              index = ["a","b","c","d","e","f"])
s
# Out:
# a    21
# b    26
# c    23
# d    25
# e    24
# f    26
# Name: Age, dtype: int64

# %%
s['b']
# Out:
# 26

# %%
s.sum()
# Out:
# 145

# %%
s.mean()
# Out:
# 24.166666666666668

# %%
df = pd.DataFrame({
    "name": ['a','b','c','d','e','f'],
    "age": [23,24,25,26,27,28]
})
df
# Out:
#   name  age
# 0    a   23
# 1    b   24
# 2    c   25
# 3    d   26
# 4    e   27
# 5    f   28

# %%
df.set_index("age")
# Out:
#     name
# age
# 23     a
# 24     b
# 25     c
# 26     d
# 27     e
# 28     f

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   6.000000
# mean   25.500000
# std     1.870829
# min    23.000000
# 25%    24.250000
# 50%    25.500000
# 75%    26.750000
# max    28.000000

# %%
df =pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\test.csv")
df.head()
# Out:
#      Name  Age Course  Completion Country     ID Hostel no.        Food  \
# 0   Ankur   20    bba        2015   India  10010         4a  Vegeterian
# 1  Shivin   22    mba        2013      BD  10011         5b  Vegeterian
# 2  Chitra   25    bba        2018   China  10012         6a     Non-Veg
# 3   Samar   24    mba        2019  Africa  10013         1b     Non-Veg
# 4  Robert   25    CSE        2020  Africa  10014         2b  Vegeterian
#
#        Fees
# 0      Paid
# 1      Paid
# 2  Not Paid
# 3      Paid
# 4      Paid

# %%
df.tail()
# Out:
#      Name  Age      Course  Completion   Country     ID Hostel no.  \
# 4  Robert   25         CSE        2020    Africa  10014         2b
# 5    John   26         mba        2021        BD  10015         3a
# 6    Paul   27         bba        2010     India  10016         5a
# 7     Tom   21  mechanical        2023     China  10017         6b
# 8   Reddy   29         mba        2022  Malaysia  10018         4b
#
#          Food      Fees
# 4  Vegeterian      Paid
# 5     Non-Veg  Not Paid
# 6     Non-Veg  Not Paid
# 7     Non-Veg      Paid
# 8     Non-Veg      Paid

# %%
df.describe()
# Out:
#              Age   Completion            ID
# count   9.000000     9.000000      9.000000
# mean   24.333333  2017.888889  10014.000000
# std     2.915476     4.371626      2.738613
# min    20.000000  2010.000000  10010.000000
# 25%    22.000000  2015.000000  10012.000000
# 50%    25.000000  2019.000000  10014.000000
# 75%    26.000000  2021.000000  10016.000000
# max    29.000000  2023.000000  10018.000000

# %%
df[(df["Age"]>25) | (df["ID"]>10014)]
# Out:
#     Name  Age      Course  Completion   Country     ID Hostel no.     Food  \
# 5   John   26         mba        2021        BD  10015         3a  Non-Veg
# 6   Paul   27         bba        2010     India  10016         5a  Non-Veg
# 7    Tom   21  mechanical        2023     China  10017         6b  Non-Veg
# 8  Reddy   29         mba        2022  Malaysia  10018         4b  Non-Veg
#
#        Fees
# 5  Not Paid
# 6  Not Paid
# 7      Paid
# 8      Paid

# %%
df[(df["Age"]<26) & (df["Food"]=="Non-Veg")]
# Out:
#      Name  Age      Course  Completion Country     ID Hostel no.     Food  \
# 2  Chitra   25         bba        2018   China  10012         6a  Non-Veg
# 3   Samar   24         mba        2019  Africa  10013         1b  Non-Veg
# 7     Tom   21  mechanical        2023   China  10017         6b  Non-Veg
#
#        Fees
# 2  Not Paid
# 3      Paid
# 7      Paid

# %%
df[~(df["Food"]=="Non-Veg")]
# Out:
#      Name  Age Course  Completion Country     ID Hostel no.        Food  Fees
# 0   Ankur   20    bba        2015   India  10010         4a  Vegeterian  Paid
# 1  Shivin   22    mba        2013      BD  10011         5b  Vegeterian  Paid
# 4  Robert   25    CSE        2020  Africa  10014         2b  Vegeterian  Paid

# %%
df[~(df["Food"]=="Vegeterian")]
# Out:
#      Name  Age      Course  Completion   Country     ID Hostel no.     Food  \
# 2  Chitra   25         bba        2018     China  10012         6a  Non-Veg
# 3   Samar   24         mba        2019    Africa  10013         1b  Non-Veg
# 5    John   26         mba        2021        BD  10015         3a  Non-Veg
# 6    Paul   27         bba        2010     India  10016         5a  Non-Veg
# 7     Tom   21  mechanical        2023     China  10017         6b  Non-Veg
# 8   Reddy   29         mba        2022  Malaysia  10018         4b  Non-Veg
#
#        Fees
# 2  Not Paid
# 3      Paid
# 5  Not Paid
# 6  Not Paid
# 7      Paid
# 8      Paid

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Course', 'Completion', 'Country', 'ID', 'Hostel no.',
#        'Food', 'Fees'],
#       dtype='object')

# %%
df.Name
# Out:
# 0     Ankur
# 1    Shivin
# 2    Chitra
# 3     Samar
# 4    Robert
# 5      John
# 6      Paul
# 7       Tom
# 8     Reddy
# Name: Name, dtype: object

# %%
df.rename(columns={"Completion":"Graduation"})
# Out:
#      Name  Age      Course  Graduation   Country     ID Hostel no.  \
# 0   Ankur   20         bba        2015     India  10010         4a
# 1  Shivin   22         mba        2013        BD  10011         5b
# 2  Chitra   25         bba        2018     China  10012         6a
# 3   Samar   24         mba        2019    Africa  10013         1b
# 4  Robert   25         CSE        2020    Africa  10014         2b
# 5    John   26         mba        2021        BD  10015         3a
# 6    Paul   27         bba        2010     India  10016         5a
# 7     Tom   21  mechanical        2023     China  10017         6b
# 8   Reddy   29         mba        2022  Malaysia  10018         4b
#
#          Food      Fees
# 0  Vegeterian      Paid
# 1  Vegeterian      Paid
# 2     Non-Veg  Not Paid
# 3     Non-Veg      Paid
# 4  Vegeterian      Paid
# 5     Non-Veg  Not Paid
# 6     Non-Veg  Not Paid
# 7     Non-Veg      Paid
# 8     Non-Veg      Paid

# %%
df.rename(columns={"ID":"ID No"})
# Out:
#      Name  Age      Course  Completion   Country  ID No Hostel no.  \
# 0   Ankur   20         bba        2015     India  10010         4a
# 1  Shivin   22         mba        2013        BD  10011         5b
# 2  Chitra   25         bba        2018     China  10012         6a
# 3   Samar   24         mba        2019    Africa  10013         1b
# 4  Robert   25         CSE        2020    Africa  10014         2b
# 5    John   26         mba        2021        BD  10015         3a
# 6    Paul   27         bba        2010     India  10016         5a
# 7     Tom   21  mechanical        2023     China  10017         6b
# 8   Reddy   29         mba        2022  Malaysia  10018         4b
#
#          Food      Fees
# 0  Vegeterian      Paid
# 1  Vegeterian      Paid
# 2     Non-Veg  Not Paid
# 3     Non-Veg      Paid
# 4  Vegeterian      Paid
# 5     Non-Veg  Not Paid
# 6     Non-Veg  Not Paid
# 7     Non-Veg      Paid
# 8     Non-Veg      Paid

# %%
d = df.reset_index()    
d
# Out:
#    index    Name  Age      Course  Completion   Country     ID Hostel no.  \
# 0      0   Ankur   20         bba        2015     India  10010         4a
# 1      1  Shivin   22         mba        2013        BD  10011         5b
# 2      2  Chitra   25         bba        2018     China  10012         6a
# 3      3   Samar   24         mba        2019    Africa  10013         1b
# 4      4  Robert   25         CSE        2020    Africa  10014         2b
# 5      5    John   26         mba        2021        BD  10015         3a
# 6      6    Paul   27         bba        2010     India  10016         5a
# 7      7     Tom   21  mechanical        2023     China  10017         6b
# 8      8   Reddy   29         mba        2022  Malaysia  10018         4b
#
#          Food      Fees
# 0  Vegeterian      Paid
# 1  Vegeterian      Paid
# 2     Non-Veg  Not Paid
# 3     Non-Veg      Paid
# 4  Vegeterian      Paid
# 5     Non-Veg  Not Paid
# 6     Non-Veg  Not Paid
# 7     Non-Veg      Paid
# ...

# %%
df.set_index("Name")
# Out:
#         Age      Course  Completion   Country     ID Hostel no.        Food  \
# Name
# Ankur    20         bba        2015     India  10010         4a  Vegeterian
# Shivin   22         mba        2013        BD  10011         5b  Vegeterian
# Chitra   25         bba        2018     China  10012         6a     Non-Veg
# Samar    24         mba        2019    Africa  10013         1b     Non-Veg
# Robert   25         CSE        2020    Africa  10014         2b  Vegeterian
# John     26         mba        2021        BD  10015         3a     Non-Veg
# Paul     27         bba        2010     India  10016         5a     Non-Veg
# Tom      21  mechanical        2023     China  10017         6b     Non-Veg
# Reddy    29         mba        2022  Malaysia  10018         4b     Non-Veg
#
#             Fees
# Name
# Ankur       Paid
# Shivin      Paid
# Chitra  Not Paid
# Samar       Paid
# Robert      Paid
# John    Not Paid
# Paul    Not Paid
# Tom         Paid
# Reddy       Paid

# %%
d = df.reset_index()
d
# Out:
#    index    Name  Age      Course  Completion   Country     ID Hostel no.  \
# 0      0   Ankur   20         bba        2015     India  10010         4a
# 1      1  Shivin   22         mba        2013        BD  10011         5b
# 2      2  Chitra   25         bba        2018     China  10012         6a
# 3      3   Samar   24         mba        2019    Africa  10013         1b
# 4      4  Robert   25         CSE        2020    Africa  10014         2b
# 5      5    John   26         mba        2021        BD  10015         3a
# 6      6    Paul   27         bba        2010     India  10016         5a
# 7      7     Tom   21  mechanical        2023     China  10017         6b
# 8      8   Reddy   29         mba        2022  Malaysia  10018         4b
#
#          Food      Fees
# 0  Vegeterian      Paid
# 1  Vegeterian      Paid
# 2     Non-Veg  Not Paid
# 3     Non-Veg      Paid
# 4  Vegeterian      Paid
# 5     Non-Veg  Not Paid
# 6     Non-Veg  Not Paid
# 7     Non-Veg      Paid
# ...

# %%
df["Age"][5] = 31   
df["Age"]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_7368/4129914878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"][5] = 31
# 0    20
# 1    22
# 2    25
# 3    24
# 4    25
# 5    31
# 6    27
# 7    21
# 8    29
# Name: Age, dtype: int64

# %%
df["Age"].unique()
# Out:
# array([20, 22, 25, 24, 31, 27, 21, 29], dtype=int64)

# %%
df[df["Country"].isin(['India','BD','China'])]
# Out:
#      Name  Age      Course  Completion Country     ID Hostel no.        Food  \
# 0   Ankur   20         bba        2015   India  10010         4a  Vegeterian
# 1  Shivin   22         mba        2013      BD  10011         5b  Vegeterian
# 2  Chitra   25         bba        2018   China  10012         6a     Non-Veg
# 5    John   31         mba        2021      BD  10015         3a     Non-Veg
# 6    Paul   27         bba        2010   India  10016         5a     Non-Veg
# 7     Tom   21  mechanical        2023   China  10017         6b     Non-Veg
#
#        Fees
# 0      Paid
# 1      Paid
# 2  Not Paid
# 5  Not Paid
# 6  Not Paid
# 7      Paid

# %%
df[df["Course"].isin(['bba','mba'])]
# Out:
#      Name  Age Course  Completion   Country     ID Hostel no.        Food  \
# 0   Ankur   20    bba        2015     India  10010         4a  Vegeterian
# 1  Shivin   22    mba        2013        BD  10011         5b  Vegeterian
# 2  Chitra   25    bba        2018     China  10012         6a     Non-Veg
# 3   Samar   24    mba        2019    Africa  10013         1b     Non-Veg
# 5    John   31    mba        2021        BD  10015         3a     Non-Veg
# 6    Paul   27    bba        2010     India  10016         5a     Non-Veg
# 8   Reddy   29    mba        2022  Malaysia  10018         4b     Non-Veg
#
#        Fees
# 0      Paid
# 1      Paid
# 2  Not Paid
# 3      Paid
# 5  Not Paid
# 6  Not Paid
# 8      Paid

# %% [markdown]
# df.where(df['Name']=='Shivin')

# %%
df.shape
# Out:
# (9, 9)

# %%
df = pd.DataFrame({
    'Name' : ['a','b','c','d','e','f'],
    'Age' : [20,21,22,None,24,25]
})

# %%
df.dropna()
# Out:
#   Name   Age
# 0    a  20.0
# 1    b  21.0
# 2    c  22.0
# 4    e  24.0
# 5    f  25.0

# %%
df.dropna(axis=1) #it will discard the colum which has null value
# Out:
#   Name
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f

# %%
df = pd.DataFrame({
    'Name':['a','b','c','d','e'],
    'Age': [20,21,22, ,24]
})
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_7368/207740799.py", line 3
#     'Age': [20,21,22, ,24]
#                       ^
# SyntaxError: invalid syntax

# %%
df.fillna(23)
# Out:
#   Name   Age
# 0    a  20.0
# 1    b  21.0
# 2    c  22.0
# 3    d  23.0
# 4    e  24.0
# 5    f  25.0

# %%
import pandas as pd
a = ['1','2','3','4']
var = pd.Series(a)
print(a)
# Out:
# ['1', '2', '3', '4']

# %%
print(var[2])
# Out:
# 3

# %%
a = ['1','2','3']
var = pd.Series(a, index= ["x","y","z"])
print(var)
# Out:
# x    1
# y    2
# z    3
# dtype: object

# %%
print(var["y"])
# Out:
# 2

# %%
calory = {"day1":160,"day2":190,"day3":200}
var = pd.Series(calory)
print(var)
# Out:
# day1    160
# day2    190
# day3    200
# dtype: int64

# %%
calory = {"day1":160,"day2":260,"day3":240}
var = pd.Series(calory, index=["day1","day2"])
print(var)
# Out:
# day1    160
# day2    260
# dtype: int64

# %%
data = {
    "name" : ['a','b','c'],
    "age" : [12,20,26]
}
val = pd.DataFrame(data)
print(val)
# Out:
#   name  age
# 0    a   12
# 1    b   20
# 2    c   26

# %%
print(val.loc[0])
# Out:
# name     a
# age     12
# Name: 0, dtype: object

# %%
print(val.loc[[0,1]])
# Out:
#   name  age
# 0    a   12
# 1    b   20

# %%
data = {
    'name' : ['a','b','c'],
    'age' : [20,25,26]
}
val = pd.DataFrame(data, index=['day1','day2','day3'])
print(val)
# Out:
#      name  age
# day1    a   20
# day2    b   25
# day3    c   26

# %%
val.reset_index()
# Out:
#   index name  age
# 0  day1    a   20
# 1  day2    b   25
# 2  day3    c   26

# %%
val.set_index("name")
# Out:
#       age
# name
# a      20
# b      25
# c      26

# %%
val.loc["day2"]
# Out:
# name     b
# age     25
# Name: day2, dtype: object

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\user\\OneDrive\\Desktop\\calory.csv')
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/05/20'    110       140    400.02
# 1         60  2020/04/15'    100       150    450.20
# 2         60  2020/06/12'    110       140    250.30
# 3         60  2020/06/12'    110       140    250.30
# 4         60  2020/09/02'    120       155    450.70
# 5         45          NaN    100       150    250.60
# 6         50  2020/04/11'    120       130    460.80
# 7        250  2020/05/23'    125       135       NaN
# 8         60   10/17/2020     90       140    500.40
# 9         50  2020/06/15'     95       150    640.50
# 10       250  2021/04/28'    100       140    230.30
# 11        40  2020/05/29'     90       145    505.50
# 12        60  2020/06/28'     85       150    260.00
# 13        65  2020/02/23'    100       155    290.20

# %%
df = pd.read_csv('C:\\Users\\user\\OneDrive\\Desktop\\calory.csv')
df.head()
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/05/20'    110       140    400.02
# 1        60  2020/04/15'    100       150    450.20
# 2        60  2020/06/12'    110       140    250.30
# 3        60  2020/06/12'    110       140    250.30
# 4        60  2020/09/02'    120       155    450.70

# %%
new_df = df.dropna()
print(new_df.to_string())
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/05/20'    110       140    400.02
# 1         60  2020/04/15'    100       150    450.20
# 2         60  2020/06/12'    110       140    250.30
# 3         60  2020/06/12'    110       140    250.30
# 4         60  2020/09/02'    120       155    450.70
# 6         50  2020/04/11'    120       130    460.80
# 8         60   10/17/2020     90       140    500.40
# 9         50  2020/06/15'     95       150    640.50
# 10       250  2021/04/28'    100       140    230.30
# 11        40  2020/05/29'     90       145    505.50
# 12        60  2020/06/28'     85       150    260.00
# 13        65  2020/02/23'    100       155    290.20

# %%
new_df = df.dropna()
new_df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/05/20'    110       140    400.02
# 1         60  2020/04/15'    100       150    450.20
# 2         60  2020/06/12'    110       140    250.30
# 3         60  2020/06/12'    110       140    250.30
# 4         60  2020/09/02'    120       155    450.70
# 6         50  2020/04/11'    120       130    460.80
# 8         60   10/17/2020     90       140    500.40
# 9         50  2020/06/15'     95       150    640.50
# 10       250  2021/04/28'    100       140    230.30
# 11        40  2020/05/29'     90       145    505.50
# 12        60  2020/06/28'     85       150    260.00
# 13        65  2020/02/23'    100       155    290.20

# %%
new_df = df.fillna(130)
new_df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/05/20'    110       140    400.02
# 1         60  2020/04/15'    100       150    450.20
# 2         60  2020/06/12'    110       140    250.30
# 3         60  2020/06/12'    110       140    250.30
# 4         60  2020/09/02'    120       155    450.70
# 5         45          130    100       150    250.60
# 6         50  2020/04/11'    120       130    460.80
# 7        250  2020/05/23'    125       135    130.00
# 8         60   10/17/2020     90       140    500.40
# 9         50  2020/06/15'     95       150    640.50
# 10       250  2021/04/28'    100       140    230.30
# 11        40  2020/05/29'     90       145    505.50
# 12        60  2020/06/28'     85       150    260.00
# 13        65  2020/02/23'    100       155    290.20

# %%
new_df = df["Calories"].fillna(170)
new_df
# Out:
# 0     400.02
# 1     450.20
# 2     250.30
# 3     250.30
# 4     450.70
# 5     250.60
# 6     460.80
# 7     170.00
# 8     500.40
# 9     640.50
# 10    230.30
# 11    505.50
# 12    260.00
# 13    290.20
# Name: Calories, dtype: float64

# %%
x = df["Calories"].mean()
new_df = df.fillna(x)
new_df
# Out:
#     Duration         Date  Pulse  Maxpulse    Calories
# 0         60  2020/05/20'    110       140  400.020000
# 1         60  2020/04/15'    100       150  450.200000
# 2         60  2020/06/12'    110       140  250.300000
# 3         60  2020/06/12'    110       140  250.300000
# 4         60  2020/09/02'    120       155  450.700000
# 5         45   379.986154    100       150  250.600000
# 6         50  2020/04/11'    120       130  460.800000
# 7        250  2020/05/23'    125       135  379.986154
# 8         60   10/17/2020     90       140  500.400000
# 9         50  2020/06/15'     95       150  640.500000
# 10       250  2021/04/28'    100       140  230.300000
# 11        40  2020/05/29'     90       145  505.500000
# 12        60  2020/06/28'     85       150  260.000000
# 13        65  2020/02/23'    100       155  290.200000

# %%
x = df["Calories"].median()
new_df = df.fillna(x)
new_df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/05/20'    110       140    400.02
# 1         60  2020/04/15'    100       150    450.20
# 2         60  2020/06/12'    110       140    250.30
# 3         60  2020/06/12'    110       140    250.30
# 4         60  2020/09/02'    120       155    450.70
# 5         45       400.02    100       150    250.60
# 6         50  2020/04/11'    120       130    460.80
# 7        250  2020/05/23'    125       135    400.02
# 8         60   10/17/2020     90       140    500.40
# 9         50  2020/06/15'     95       150    640.50
# 10       250  2021/04/28'    100       140    230.30
# 11        40  2020/05/29'     90       145    505.50
# 12        60  2020/06/28'     85       150    260.00
# 13        65  2020/02/23'    100       155    290.20

# %%
x = df["Calories"].mode()[0]
new_df= df.fillna(x)
new_df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/05/20'    110       140    400.02
# 1         60  2020/04/15'    100       150    450.20
# 2         60  2020/06/12'    110       140    250.30
# 3         60  2020/06/12'    110       140    250.30
# 4         60  2020/09/02'    120       155    450.70
# 5         45        250.3    100       150    250.60
# 6         50  2020/04/11'    120       130    460.80
# 7        250  2020/05/23'    125       135    250.30
# 8         60   10/17/2020     90       140    500.40
# 9         50  2020/06/15'     95       150    640.50
# 10       250  2021/04/28'    100       140    230.30
# 11        40  2020/05/29'     90       145    505.50
# 12        60  2020/06/28'     85       150    260.00
# 13        65  2020/02/23'    100       155    290.20

# %%
df["Date"] = pd.to_datetime(df["Date"])
print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-05-20    110       140    400.02
# 1         60 2020-04-15    100       150    450.20
# 2         60 2020-06-12    110       140    250.30
# 3         60 2020-06-12    110       140    250.30
# 4         60 2020-09-02    120       155    450.70
# 5         45        NaT    100       150    250.60
# 6         50 2020-04-11    120       130    460.80
# 7        250 2020-05-23    125       135       NaN
# 8         60 2020-10-17     90       140    500.40
# 9         50 2020-06-15     95       150    640.50
# 10       250 2021-04-28    100       140    230.30
# 11        40 2020-05-29     90       145    505.50
# 12        60 2020-06-28     85       150    260.00
# 13        65 2020-02-23    100       155    290.20

# %%
df.dropna(subset=['Date'])   #to drop the naT value which is handled as null
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-05-20    110       140    400.02
# 1         60 2020-04-15    100       150    450.20
# 2         60 2020-06-12    110       140    250.30
# 3         60 2020-06-12    110       140    250.30
# 4         60 2020-09-02    120       155    450.70
# 6         50 2020-04-11    120       130    460.80
# 7        250 2020-05-23    125       135       NaN
# 8         60 2020-10-17     90       140    500.40
# 9         50 2020-06-15     95       150    640.50
# 10       250 2021-04-28    100       140    230.30
# 11        40 2020-05-29     90       145    505.50
# 12        60 2020-06-28     85       150    260.00
# 13        65 2020-02-23    100       155    290.20

# %%
df.dropna(subset=["Calories"])
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-05-20    110       140    400.02
# 1         60 2020-04-15    100       150    450.20
# 2         60 2020-06-12    110       140    250.30
# 3         60 2020-06-12    110       140    250.30
# 4         60 2020-09-02    120       155    450.70
# 5         45        NaT    100       150    250.60
# 6         50 2020-04-11    120       130    460.80
# 8         60 2020-10-17     90       140    500.40
# 9         50 2020-06-15     95       150    640.50
# 10       250 2021-04-28    100       140    230.30
# 11        40 2020-05-29     90       145    505.50
# 12        60 2020-06-28     85       150    260.00
# 13        65 2020-02-23    100       155    290.20

# %%
df.Pulse
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7368/287651432.py in <module>
# ----> 1 df.Pulse
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Pulse'

# %%
df.drop_duplicates()
